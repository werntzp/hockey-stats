# %%
# test version (should be minimum 4.1.0)
import plotly
plotly.__version__
# Out:
# '4.1.1'

# %%
# install new version if we need to
# !pip install plotly==4.1.0
# !pip install orca
# !pip install psutil

# %%
#@title
# Get this figure: fig = py.get_figure("https://plot.ly/~grov3r/19/")
# Get this figure's data: data = py.get_figure("https://plot.ly/~grov3r/19/").get_data()
# Add data to this figure: py.plot(Data([Scatter(x=[1, 2], y=[2, 3])]), filename ="plot from API (5)", fileopt="extend")
# Get y data of first trace: y1 = py.get_figure("https://plot.ly/~grov3r/19/").get_data()[0]["y"]

# Get figure documentation: https://plot.ly/python/get-requests/
# Add data documentation: https://plot.ly/python/file-options/

# If you're using unicode in your file, you may need to specify the encoding.
# You can reproduce this figure in Python with the following code!

# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

import plotly.graph_objects as go
from plotly.graph_objs import *

trace1 = {
  "uid": "75dd217b-50c0-42d0-9f28-2c9760cc87f9", 
  "mode": "markers", 
  "type": "scatter", 
  "x": [ -50, 90, -85, -90, -125, 50, 45, 40, 60, 135, 100, 150, 150, 150, 160, 155, 110, 90, 85, 85, 40, 0, 0, 10, -50, -45, -45, -45, -85, -125, -125, -120, -150],
  "y": [ 495, 450, 465, 425, 355, 490, 485, 460, 460, 450, 425, 425, 390, 380, 360, 355, 355, 360, 355, 360, 410, 410, 390, 380, 480, 425, 400, 355, 355, 330, 430, 450, 410 ],
  "marker": {"size": 4}
}

data = Data([trace1])
layout = {
  "title": {"text": "Ice Hockey Rink Outline"}, 
  "width": 500, 
  "xaxis": {
    "type": "linear", 
    "range": [-250.73746312684366, 250.73746312684366], 
    "autorange": True
  }, 
  "yaxis": {
    "type": "linear", 
    "range": [-87.71108742004265, 580.7110874200426], 
    "autorange": True
  }, 
  "height": 650, 
  "shapes": [
    {
      "x0": "-250", 
      "x1": "250", 
      "y0": "0", 
      "y1": "516.2", 
      "line": {"width": 1}, 
      "type": "rect", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "200", 
      "x1": "-200", 
      "y0": "580", 
      "y1": "580", 
      "line": {"width": 1}, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "line": {"width": 1}, 
      "path": "M 200 580 C 217 574, 247 532, 250 516.2", 
      "type": "path", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "line": {"width": 1}, 
      "path": "M -200 580 C -217 574, -247 532, -250 516.2", 
      "type": "path", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "64.7", 
      "x1": "82.3", 
      "y0": "516.2", 
      "y1": "580", 
      "line": {"width": 1}, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-64.7", 
      "x1": "-82.3", 
      "y0": "516.2", 
      "y1": "580", 
      "line": {"width": 1}, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "23.5", 
      "x1": "23.5", 
      "y0": "516.2", 
      "y1": "493", 
      "line": {"width": 1}, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-23.5", 
      "x1": "-23.5", 
      "y0": "516.2", 
      "y1": "493", 
      "line": {"width": 1}, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "line": {"width": 1}, 
      "path": "M 23.5 493 C 20 480, -20 480, -23.5 493", 
      "type": "path", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "line": {"width": 1}, 
      "path": "M 17.6 516.2 C 15 530, -15 530, -17.6 516.2", 
      "type": "path", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-250", 
      "x1": "250", 
      "y0": "516.2", 
      "y1": "516.2", 
      "line": {"width": 1}, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "250", 
      "x1": "-250", 
      "y0": "150.8", 
      "y1": "145", 
      "line": {
        "color": "rgba(0, 0, 255, 1)", 
        "width": 1
      }, 
      "type": "rect", 
      "xref": "x", 
      "yref": "y", 
      "fillcolor": "rgba(0, 0, 255, 0.8)"
    }, 
    {
      "x0": "88.2", 
      "x1": "-88.2", 
      "y0": "87", 
      "y1": "-87", 
      "line": {
        "color": "rgba(0, 0, 255, 1)", 
        "width": 1
      }, 
      "type": "circle", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-135.5", 
      "x1": "-123.5", 
      "y0": "121.8", 
      "y1": "110.2", 
      "line": {
        "color": "rgba(200, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "circle", 
      "xref": "x", 
      "yref": "y", 
      "fillcolor": "rgba(200, 0, 0, 1)"
    }, 
    {
      "x0": "135.5", 
      "x1": "123.5", 
      "y0": "121.8", 
      "y1": "110.2", 
      "line": {
        "color": "rgba(200, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "circle", 
      "xref": "x", 
      "yref": "y", 
      "fillcolor": "rgba(200, 0, 0, 1)"
    }, 
    {
      "x0": "217.6", 
      "x1": "41.2", 
      "y0": "487.2", 
      "y1": "313.2", 
      "line": {
        "color": "rgba(255, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "circle", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-217.6", 
      "x1": "-41.2", 
      "y0": "487.2", 
      "y1": "313.2", 
      "line": {
        "color": "rgba(255, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "circle", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-135.5", 
      "x1": "-123.5", 
      "y0": "406", 
      "y1": "394.4", 
      "line": {
        "color": "rgba(200, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "circle", 
      "xref": "x", 
      "yref": "y", 
      "fillcolor": "rgba(200, 0, 0, 1)"
    }, 
    {
      "x0": "135.5", 
      "x1": "123.5", 
      "y0": "406", 
      "y1": "394.4", 
      "line": {
        "color": "rgba(200, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "circle", 
      "xref": "x", 
      "yref": "y", 
      "fillcolor": "rgba(200, 0, 0, 1)"
    }, 
    {
      "x0": "141.17", 
      "x1": "141.17", 
      "y0": "423.4", 
      "y1": "377", 
      "line": {
        "color": "rgba(10, 10, 100, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "117.62", 
      "x1": "117.62", 
      "y0": "423.4", 
      "y1": "377", 
      "line": {
        "color": "rgba(10, 10, 100, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-141.17", 
      "x1": "-141.17", 
      "y0": "423.4", 
      "y1": "377", 
      "line": {
        "color": "rgba(10, 10, 100, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-117.62", 
      "x1": "-117.62", 
      "y0": "423.4", 
      "y1": "377", 
      "line": {
        "color": "rgba(10, 10, 100, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "153", 
      "x1": "105.8", 
      "y0": "406", 
      "y1": "406", 
      "line": {
        "color": "rgba(10, 10, 100, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "153", 
      "x1": "105.8", 
      "y0": "394.4", 
      "y1": "394.4", 
      "line": {
        "color": "rgba(10, 10, 100, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-153", 
      "x1": "-105.8", 
      "y0": "406", 
      "y1": "406", 
      "line": {
        "color": "rgba(10, 10, 100, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-153", 
      "x1": "-105.8", 
      "y0": "394.4", 
      "y1": "394.4", 
      "line": {
        "color": "rgba(10, 10, 100, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "230", 
      "x1": "217.8", 
      "y0": "416.4", 
      "y1": "416.4", 
      "line": {
        "color": "rgba(255, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "230", 
      "x1": "217.8", 
      "y0": "384", 
      "y1": "384", 
      "line": {
        "color": "rgba(255, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-230", 
      "x1": "-217.8", 
      "y0": "416.4", 
      "y1": "416.4", 
      "line": {
        "color": "rgba(255, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-230", 
      "x1": "-217.8", 
      "y0": "384", 
      "y1": "384", 
      "line": {
        "color": "rgba(255, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-250", 
      "x1": "250", 
      "y0": "0", 
      "y1": "0", 
      "line": {
        "color": "rgba(255, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "-250", 
      "x1": "250", 
      "y0": "516.2", 
      "y1": "516.2", 
      "line": {
        "color": "rgba(255, 0, 0, 1)", 
        "width": 1
      }, 
      "type": "line", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x0": "2.94", 
      "x1": "-2.94", 
      "y0": "2.8", 
      "y1": "-2.8", 
      "line": {
        "color": "rgba(0, 0, 255, 1)", 
        "width": 1
      }, 
      "type": "circle", 
      "xref": "x", 
      "yref": "y", 
      "fillcolor": "rgba(0, 0, 255, 1)"
    }
  ]
}


fig = go.Figure(data=data, layout=layout)
fig.show()
#fig.write_image("/content/wk1_shot_map.png")
# Out:
# /usr/local/lib/python3.6/dist-packages/plotly/graph_objs/_deprecations.py:40: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0c5b660f-5cf4-49ac-b36d-dcdd446cb32a" class="plotly-graph-div" style="height:650px; width:500px;"></div>
# ...
